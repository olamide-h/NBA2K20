# %%
#Read IN DATA SET

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('nba2k-full.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439 entries, 0 to 438
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   full_name    439 non-null    object
#  1   rating       439 non-null    int64
#  2   jersey       439 non-null    object
#  3   team         416 non-null    object
#  4   position     439 non-null    object
#  5   b_day        439 non-null    object
#  6   height       439 non-null    object
#  7   weight       439 non-null    object
#  8   salary       439 non-null    object
#  9   country      439 non-null    object
#  10  draft_year   439 non-null    int64
#  11  draft_round  439 non-null    object
#  12  draft_peak   439 non-null    object
#  13  college      370 non-null    object
#  14  version      439 non-null    object
# dtypes: int64(2), object(13)
# memory usage: 51.6+ KB

# %%
df.head()
# Out:
#                full_name  rating jersey                  team position  \
# 0           LeBron James      97    #23    Los Angeles Lakers        F
# 1          Kawhi Leonard      97     #2  Los Angeles Clippers        F
# 2  Giannis Antetokounmpo      96    #34       Milwaukee Bucks      F-G
# 3           Kevin Durant      96     #7         Brooklyn Nets        F
# 4           James Harden      96    #13       Houston Rockets        G
#
#       b_day       height                weight     salary country  draft_year  \
# 0  12/30/84   6-9 / 2.06  250 lbs. / 113.4 kg.  $37436858     USA        2003
# 1  06/29/91   6-7 / 2.01  225 lbs. / 102.1 kg.  $32742000     USA        2011
# 2  12/06/94  6-11 / 2.11  242 lbs. / 109.8 kg.  $25842697  Greece        2013
# 3  09/29/88  6-10 / 2.08  230 lbs. / 104.3 kg.  $37199000     USA        2007
# 4  08/26/89   6-5 / 1.96   220 lbs. / 99.8 kg.  $38199000     USA        2009
#
#   draft_round draft_peak          college  version
# ...

# %%
df.describe()
# Out:
#            rating   draft_year
# count  439.000000   439.000000
# mean    76.797267  2014.018223
# std      6.251750     3.967290
# min     67.000000  2001.000000
# 25%     72.000000  2012.000000
# 50%     75.000000  2015.000000
# 75%     79.000000  2017.000000
# max     97.000000  2019.000000

# %%
df.groupby('team')

# %%
df
# Out:
#                  full_name  rating jersey                    team position  \
# 0             LeBron James      97    #23      Los Angeles Lakers        F
# 1            Kawhi Leonard      97     #2    Los Angeles Clippers        F
# 2    Giannis Antetokounmpo      96    #34         Milwaukee Bucks      F-G
# 3             Kevin Durant      96     #7           Brooklyn Nets        F
# 4             James Harden      96    #13         Houston Rockets        G
# ..                     ...     ...    ...                     ...      ...
# 434           Kevin Durant      95     #7           Brooklyn Nets        F
# 435          Anthony Davis      95     #3      Los Angeles Lakers      F-C
# 436            Luka Doncic      94    #77        Dallas Mavericks      G-F
# 437         Damian Lillard      94     #0  Portland Trail Blazers        G
# 438            Joel Embiid      91    #21      Philadelphia 76ers        C
#
# ...

# %%
df.groupby('team').mean()

#The mean (or average) of the sales column

df.groupby('team').sum()

#The sum of the sales column

df.groupby('team').std()

#The standard deviation of the sales column
# Out:
#                           rating  draft_year
# team
# Atlanta Hawks           5.951827    2.923261
# Boston Celtics          5.378018    3.328201
# Brooklyn Nets           8.757616    4.404543
# Charlotte Hornets       2.740641    3.510302
# Chicago Bulls           4.399134    3.136574
# Cleveland Cavaliers     4.420167    3.352972
# Dallas Mavericks        6.082420    3.518996
# Denver Nuggets          5.230581    2.019139
# Detroit Pistons         5.005491    3.501962
# Golden State Warriors   9.832486    3.928528
# Houston Rockets         7.663600    4.418783
# Indiana Pacers          5.284298    2.313521
# Los Angeles Clippers    8.830143    4.011887
# Los Angeles Lakers      9.704835    4.867358
# Memphis Grizzlies       3.478874    3.526457
# Miami Heat              5.429298    4.582576
# Milwaukee Bucks         8.140113    4.850713
# Minnesota Timberwolves  5.921495    3.174417
# New Orleans Pelicans    4.468940    4.120795
# New York Knicks         3.480558    3.348063
# ...

# %%
df.groupby('team').describe()
# Out:
#                        rating                                                 \
#                         count       mean       std   min    25%   50%    75%
# team
# Atlanta Hawks            12.0  76.166667  5.951827  68.0  71.00  76.0  79.50
# Boston Celtics           14.0  77.000000  5.378018  71.0  73.00  75.0  80.00
# Brooklyn Nets            16.0  80.812500  8.757616  71.0  74.75  78.0  84.25
# Charlotte Hornets        10.0  74.800000  2.740641  69.0  73.50  75.5  76.75
# Chicago Bulls            15.0  75.733333  4.399134  71.0  72.00  75.0  78.50
# Cleveland Cavaliers      12.0  76.583333  4.420167  72.0  73.00  76.0  78.25
# Dallas Mavericks         16.0  77.937500  6.082420  72.0  74.00  76.0  77.50
# Denver Nuggets           13.0  77.769231  5.230581  70.0  75.00  77.0  79.00
# Detroit Pistons          14.0  73.857143  5.005491  68.0  72.00  73.0  74.75
# Golden State Warriors    10.0  80.700000  9.832486  70.0  71.75  78.0  88.25
# ...

# %%
df.groupby('position')

# %%
df.groupby('position').mean()

#The mean (or average) of the sales column

df.groupby('position').sum()

#The sum of the sales column

df.groupby('position').std()
# Out:
#             rating  draft_year
# position
# C         5.484750    4.368350
# C-F       4.774935    3.386247
# F         6.272469    4.105572
# F-C       6.895509    2.533559
# F-G       7.821146    4.847680
# G         6.195956    3.724512
# G-F       6.545388    4.849308

# %%
df.groupby('draft_round').describe()
# Out:
#             rating                                                     \
#              count       mean       std   min   25%   50%   75%   max
# draft_round
# 1            267.0  78.801498  6.643579  69.0  74.0  77.0  82.0  97.0
# 2            105.0  74.314286  4.451262  68.0  71.0  74.0  77.0  90.0
# Undrafted     67.0  72.701493  2.679976  67.0  71.0  73.0  74.0  80.0
#
#             draft_year                                                         \
#                  count         mean       std     min     25%     50%     75%
# draft_round
# 1                267.0  2013.640449  4.135616  2001.0  2011.0  2014.0  2017.0
# 2                105.0  2014.780952  3.909999  2003.0  2012.0  2016.0  2018.0
# Undrafted         67.0  2014.328358  3.135274  2006.0  2013.0  2015.0  2017.0
#
#
#                 max
# draft_round
# 1            2019.0
# 2            2019.0
# Undrafted    2019.0

# %%
df.hist(figsize=(20,20));

# %%
corrmat = df.corr()
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(corrmat, vmax=.8, square=True)
# Out:
# <AxesSubplot:>

# %%
df["background"] = df["salary"] + df["position"]

# %%
df['background']
# Out:
# 0        $37436858F
# 1        $32742000F
# 2      $25842697F-G
# 3        $37199000F
# 4        $38199000G
#            ...
# 434      $40918900F
# 435    $35361360F-C
# 436    $10174391G-F
# 437      $39344900G
# 438      $31579390C
# Name: background, Length: 439, dtype: object

# %%
df.corr()
# Out:
#               rating  draft_year
# rating      1.000000   -0.402023
# draft_year -0.402023    1.000000
